# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as ssn

# %%
df = pd.read_csv(r'/Users/isaganijulian/Downloads/Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
df
# Out:
# /var/folders/cp/wjt9yn4d1mvbjrvvv6c8176w0000gn/T/ipykernel_88761/2187449622.py:1: DtypeWarning: Columns (17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'/Users/isaganijulian/Downloads/Alzheimer_s_Disease_and_Healthy_Aging_Data.csv')
#                                              RowId  YearStart  YearEnd  \
# 0          BRFSS~2021~2021~9004~Q43~TOC11~AGE~RACE       2021     2021
# 1       BRFSS~2017~2017~9001~Q43~TOC11~AGE~OVERALL       2017     2017
# 2       BRFSS~2019~2019~9002~Q02~TNC02~AGE~OVERALL       2019     2019
# 3          BRFSS~2020~2020~59~Q43~TOC11~AGE~GENDER       2020     2020
# 4          BRFSS~2020~2020~33~Q03~TMC01~AGE~GENDER       2020     2020
# ...                                            ...        ...      ...
# 250932       BRFSS~2015~2015~54~Q30~TCC01~AGE~RACE       2015     2015
# 250933       BRFSS~2015~2015~40~Q35~TOC03~AGE~RACE       2015     2015
# 250934    BRFSS~2017~2017~33~Q44~TOC12~AGE~OVERALL       2017     2017
# 250935       BRFSS~2015~2015~51~Q39~TGC04~AGE~RACE       2015     2015
# 250936       BRFSS~2015~2015~49~Q02~TNC02~AGE~RACE       2015     2015
#
#        LocationAbbr                     LocationDesc Datasource  \
# 0              WEST                             West      BRFSS
# 1               NRE                        Northeast      BRFSS
# 2               MDW                          Midwest      BRFSS
# 3                US  United States, DC & Territories      BRFSS
# 4                NH                    New Hampshire      BRFSS
# ...             ...                              ...        ...
# 250932           WV                    West Virginia      BRFSS
# 250933           OK                         Oklahoma      BRFSS
# 250934           NH                    New Hampshire      BRFSS
# 250935           VA                         Virginia      BRFSS
# 250936           UT                             Utah      BRFSS
#
#                                       Class  \
# 0                            Overall Health
# 1                            Overall Health
# 2       Nutrition/Physical Activity/Obesity
# 3                            Overall Health
# 4                             Mental Health
# ...                                     ...
# 250932                    Cognitive Decline
# 250933                       Overall Health
# 250934                       Overall Health
# 250935                           Caregiving
# 250936  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question  Response  ...  \
# 0       Percentage of older adults ever told they have...       NaN  ...
# 1       Percentage of older adults ever told they have...       NaN  ...
# 2       Percentage of older adults who are eating 3 or...       NaN  ...
# 3       Percentage of older adults ever told they have...       NaN  ...
# 4       Percentage of older adults who are experiencin...       NaN  ...
# ...                                                   ...       ...  ...
# 250932  Percentage of older adults who reported subjec...       NaN  ...
# 250933  Mean number of days with activity limitations ...       NaN  ...
# 250934  Severe joint pain due to arthritis among older...       NaN  ...
# 250935  Average of 20 or more hours of care per week p...       NaN  ...
# 250936  Percentage of older adults who are eating 3 or...       NaN  ...
#
#        QuestionID ResponseID LocationID  StratificationCategoryID1  \
# 0             Q43        NaN       9004                        AGE
# 1             Q43        NaN       9001                        AGE
# 2             Q02        NaN       9002                        AGE
# 3             Q43        NaN         59                        AGE
# 4             Q03        NaN         33                        AGE
# ...           ...        ...        ...                        ...
# 250932        Q30        NaN         54                        AGE
# 250933        Q35        NaN         40                        AGE
# 250934        Q44        NaN         33                        AGE
# 250935        Q39        NaN         51                        AGE
# 250936        Q02        NaN         49                        AGE
#
#         StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0             AGE_OVERALL                      RACE               HIS
# 1                  65PLUS                   OVERALL           OVERALL
# 2             AGE_OVERALL                   OVERALL           OVERALL
# 3                  65PLUS                    GENDER            FEMALE
# 4                    5064                    GENDER            FEMALE
# ...                   ...                       ...               ...
# 250932        AGE_OVERALL                      RACE               ASN
# 250933               5064                      RACE               BLK
# 250934        AGE_OVERALL                   OVERALL           OVERALL
# 250935             65PLUS                      RACE               HIS
# 250936               5064                      RACE               HIS
#
#        StratificationCategoryID3 StratificationID3  Report
# 0                            NaN               NaN     NaN
# 1                            NaN               NaN     NaN
# 2                            NaN               NaN     NaN
# 3                            NaN               NaN     NaN
# 4                            NaN               NaN     NaN
# ...                          ...               ...     ...
# 250932                       NaN               NaN     NaN
# 250933                       NaN               NaN     NaN
# 250934                       NaN               NaN     NaN
# 250935                       NaN               NaN     NaN
# 250936                       NaN               NaN     NaN
#
# [250937 rows x 39 columns]

# %%
print(list(df.columns))
# Out:
# ['RowId', 'YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource', 'Class', 'Topic', 'Question', 'Response', 'Data_Value_Unit', 'DataValueTypeID', 'Data_Value_Type', 'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'Sample_Size', 'StratificationCategory1', 'Stratification1', 'StratificationCategory2', 'Stratification2', 'StratificationCategory3', 'Stratification3', 'Geolocation', 'ClassID', 'TopicID', 'QuestionID', 'ResponseID', 'LocationID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2', 'StratificationCategoryID3', 'StratificationID3', 'Report']

# %%
## Drop columns

#columns_to_drop = [
    #'RowId', 'LocationAbbr', 'Response',
    #'Data_Value_Unit', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 
    #'Data_Value_Footnote', 'Sample_Size', 'StratificationCategory3', 
    #'Stratification3', 'ResponseID', 'StratificationCategoryID3',
    #'StratificationID3', 'Report'
    #]
#df.drop(columns=columns_to_drop, inplace=True)

columns_to_drop_1 = ['DataValueTypeID']
df.drop(columns=columns_to_drop_1, inplace=True)

# %%
columns_with_nan = df.columns[df.isna().any()].tolist()

print("Columns with NaN values:", columns_with_nan)
# Out:
# Columns with NaN values: ['Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'StratificationCategory2', 'Stratification2', 'Geolocation']

# %%
# Fill n/a with blank
fill_na_columns = df[
    ['Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit',
     'StratificationCategory2', 'Stratification2', 'Geolocation']
]
fill_na_columns = fill_na_columns.fillna('')

#Update original df with filled columns
df.update(fill_na_columns)

df
# Out:
#         YearStart  YearEnd                     LocationDesc Datasource  \
# 0            2021     2021                             West      BRFSS
# 1            2017     2017                        Northeast      BRFSS
# 2            2019     2019                          Midwest      BRFSS
# 3            2020     2020  United States, DC & Territories      BRFSS
# 4            2020     2020                    New Hampshire      BRFSS
# ...           ...      ...                              ...        ...
# 250932       2015     2015                    West Virginia      BRFSS
# 250933       2015     2015                         Oklahoma      BRFSS
# 250934       2017     2017                    New Hampshire      BRFSS
# 250935       2015     2015                         Virginia      BRFSS
# 250936       2015     2015                             Utah      BRFSS
#
#                                       Class  \
# 0                            Overall Health
# 1                            Overall Health
# 2       Nutrition/Physical Activity/Obesity
# 3                            Overall Health
# 4                             Mental Health
# ...                                     ...
# 250932                    Cognitive Decline
# 250933                       Overall Health
# 250934                       Overall Health
# 250935                           Caregiving
# 250936  Nutrition/Physical Activity/Obesity
#
#                                                     Topic  \
# 0                            Arthritis among older adults
# 1                            Arthritis among older adults
# 2                       Eating 3 or more vegetables daily
# 3                            Arthritis among older adults
# 4                                Frequent mental distress
# ...                                                   ...
# 250932  Subjective cognitive decline or memory loss am...
# 250933          Recent activity limitations in past month
# 250934  Severe joint pain among older adults with arth...
# 250935         Intensity of caregiving among older adults
# 250936                  Eating 3 or more vegetables daily
#
#                                                  Question Data_Value_Type  \
# 0       Percentage of older adults ever told they have...      Percentage
# 1       Percentage of older adults ever told they have...      Percentage
# 2       Percentage of older adults who are eating 3 or...      Percentage
# 3       Percentage of older adults ever told they have...      Percentage
# 4       Percentage of older adults who are experiencin...      Percentage
# ...                                                   ...             ...
# 250932  Percentage of older adults who reported subjec...      Percentage
# 250933  Mean number of days with activity limitations ...            Mean
# 250934  Severe joint pain due to arthritis among older...      Percentage
# 250935  Average of 20 or more hours of care per week p...      Percentage
# 250936  Percentage of older adults who are eating 3 or...      Percentage
#
#        Data_Value Low_Confidence_Limit  ...         Stratification2  \
# 0            31.6                 28.8  ...                Hispanic
# 1            50.3                 49.1  ...
# 2            14.3                 13.8  ...
# 3            55.5                 54.5  ...                  Female
# 4            15.2                 12.8  ...                  Female
# ...           ...                  ...  ...                     ...
# 250932                                  ...  Asian/Pacific Islander
# 250933        7.1                  4.7  ...     Black, non-Hispanic
# 250934       21.9                 19.5  ...
# 250935                                  ...                Hispanic
# 250936       28.9                 20.1  ...                Hispanic
#
#                                            Geolocation ClassID TopicID  \
# 0                                                          C01   TOC11
# 1                                                          C01   TOC11
# 2                                                          C02   TNC02
# 3                                                          C01   TOC11
# 4         POINT (-71.50036091999965 43.65595011300047)     C05   TMC01
# ...                                                ...     ...     ...
# 250932    POINT (-80.71264013499967 38.66551020200046)     C06   TCC01
# 250933    POINT (-97.52107021399968 35.47203135600046)     C01   TOC03
# 250934    POINT (-71.50036091999965 43.65595011300047)     C01   TOC12
# 250935    POINT (-78.45789046299967 37.54268067400045)     C07   TGC04
# 250936  POINT (-111.58713063499971 39.360700171000474)     C02   TNC02
#
#        QuestionID LocationID StratificationCategoryID1 StratificationID1  \
# 0             Q43       9004                       AGE       AGE_OVERALL
# 1             Q43       9001                       AGE            65PLUS
# 2             Q02       9002                       AGE       AGE_OVERALL
# 3             Q43         59                       AGE            65PLUS
# 4             Q03         33                       AGE              5064
# ...           ...        ...                       ...               ...
# 250932        Q30         54                       AGE       AGE_OVERALL
# 250933        Q35         40                       AGE              5064
# 250934        Q44         33                       AGE       AGE_OVERALL
# 250935        Q39         51                       AGE            65PLUS
# 250936        Q02         49                       AGE              5064
#
#        StratificationCategoryID2  StratificationID2
# 0                           RACE                HIS
# 1                        OVERALL            OVERALL
# 2                        OVERALL            OVERALL
# 3                         GENDER             FEMALE
# 4                         GENDER             FEMALE
# ...                          ...                ...
# 250932                      RACE                ASN
# 250933                      RACE                BLK
# 250934                   OVERALL            OVERALL
# 250935                      RACE                HIS
# 250936                      RACE                HIS
#
# [250937 rows x 24 columns]

# %%
unique_values = df['Question'].unique()
print(unique_values)
# Out:
# ['Percentage of older adults ever told they have arthritis'
#  'Percentage of older adults who are eating 3 or more vegetables daily'
#  'Percentage of older adults who are experiencing frequent mental distress'
#  'Mean number of days with activity limitations in the past month'
#  'Percentage of older adults who reported influenza vaccine within the past year'
#  'Physically unhealthy days (mean number of days in past month)'
#  'Percentage of older adults getting sufficient sleep (>6 hours)'
#  'Percentage of older adults with a lifetime diagnosis of depression'
#  'Percentage of older adults who are eating 2 or more fruits daily'
#  'Percentage of older adults who are currently obese, with a body mass index (BMI) of 30 or more'
#  'Percentage of older adults who reported binge drinking within the past 30 days'
#  'Percentage of older adults who have fallen and sustained an injury within last year'
#  'Average of 20 or more hours of care per week provided to a friend or family member'
#  'Fair or poor health among older adults with doctor-diagnosed arthritis'
#  'Percentage of older adults who self-reported that their health is "fair" or "poor"'
#  'Percentage of older adults who had a cholesterol screening within the past 5 years'
#  'Percentage of older adults who have ever been told by a health professional that they have high blood pressure'
#  'Percentage of older adults who reported subjective cognitive decline or memory loss that interferes with their ability to engage in social activities or household chores'
#  'Percentage of older adults who have smoked at least 100 cigarettes in their entire life and still smoke every day or some days'
#  'Percentage of older adults who have not had any leisure time physical activity in the past month'
#  'Percentage of older adult women who are up to date with select clinical preventive services'
#  'Percentage of older adults who reported subjective cognitive decline or memory loss that is happening more often or is getting worse in the preceding 12 months'
#  'Percentage of older adults with subjective cognitive decline or memory loss who reported talking with a health care professional about it'
#  'Percentage of older adult men who are up to date with select clinical preventive services'
#  'Percentage of older adults currently not providing care who expect to provide care for someone with health problems in the next two years'
#  'Percentage of at risk adults (have diabetes, asthma, cardiovascular disease or currently smoke) who ever had a pneumococcal vaccine'
#  'Percentage of older adults who self-reported that their health is "good", "very good", or "excellent"'
#  'Percentage of older adult women with an intact cervix who had a Pap test within the past 3 years'
#  'Percentage of older adults who provided care to a friend or family member for six months or more'
#  'Percentage of older adult women who have received a mammogram within the past 2 years'
#  'Percentage of older adults who report having lost 5 or fewer teeth due to decay or gum disease'
#  'Percentage of older adults who reported that as a result of subjective cognitive decline or memory loss that they need assistance with day-to-day activities'
#  'Percentage of older adults who report having a disability (includes limitations related to sensory or mobility impairments or a physical, mental, or emotional condition)'
#  'Percentage of older adults who provided care for a friend or family member within the past month'
#  'Percentage of older adults who have been told they have high blood pressure who report currently taking medication for their high blood pressure'
#  'Percentage of older adults without diabetes who reported a blood sugar or diabetes test within 3 years'
#  'Percentage of older adults who had either a home blood stool test within the past year or a sigmoidoscopy or colonoscopy within the past 10 years'
#  'Severe joint pain due to arthritis among older adults with doctor-diagnosed arthritis'
#  'Percentage of older adults who provided care for someone with dementia or other cognitive impairment within the past month']
